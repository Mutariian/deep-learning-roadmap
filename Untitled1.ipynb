# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 18C3-8538
#
#  Directory of C:\Users\Mutari
#
# 11/05/2025  07:28 AM    <DIR>          .
# 11/05/2025  07:28 AM    <DIR>          ..
# 10/29/2025  11:55 AM    <DIR>          .conda
# 11/03/2025  02:46 PM                67 .condarc
# 10/29/2025  07:23 PM    <DIR>          .docker
# 11/02/2025  09:11 AM    <DIR>          .espressif
# 10/29/2025  06:03 PM                97 .gitconfig
# 11/05/2025  07:28 AM    <DIR>          .ipynb_checkpoints
# 10/29/2025  12:23 PM    <DIR>          .ipython
# 10/31/2025  11:20 AM    <DIR>          .jupyter
# 11/05/2025  07:04 AM    <DIR>          .keras
# 10/29/2025  12:24 PM    <DIR>          .matplotlib
# 11/01/2025  06:45 PM                20 .python_history
# 10/26/2025  05:02 PM    <DIR>          .vscode
# 10/26/2025  04:39 PM    <DIR>          3D Objects
# 10/26/2025  04:39 PM    <DIR>          Contacts
# 11/05/2025  05:41 AM    <DIR>          Desktop
# 10/29/2025  11:51 AM    <DIR>          Documents
# 11/05/2025  06:18 AM    <DIR>          Downloads
# 10/26/2025  06:14 PM    <DIR>          esp
# 10/26/2025  04:39 PM    <DIR>          Favorites
# 10/29/2025  06:10 PM                 0 git
# 10/26/2025  04:39 PM    <DIR>          Links
# 10/29/2025  11:41 AM    <DIR>          miniconda3
# 10/29/2025  05:08 PM           183,417 ml-playground.ipynb
# 10/29/2025  12:25 PM            21,384 ML_Fundamentals.ipynb
# 11/05/2025  07:26 AM         1,244,464 mnist_model.h5
# 10/26/2025  04:39 PM    <DIR>          Music
# 10/26/2025  04:40 PM    <DIR>          OneDrive
# 10/26/2025  04:40 PM    <DIR>          Pictures
# 10/29/2025  06:05 PM                81 README.md
# 10/26/2025  04:39 PM    <DIR>          Saved Games
# 10/29/2025  05:01 PM    <DIR>          scikit_learn_data
# 10/26/2025  04:40 PM    <DIR>          Searches
# 11/02/2025  12:25 PM             2,037 Untitled.ipynb
# 11/05/2025  07:28 AM                72 Untitled1.ipynb
# 10/29/2025  11:14 PM    <DIR>          Videos
# 11/05/2025  07:26 AM           123,332 week3_first_neural_network.ipynb
#               11 File(s)      1,574,971 bytes
#               27 Dir(s)  44,054,769,664 bytes free

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.20.0

# %%
model = keras.models.load_model("mnist_model.h5")
print("✅ Model loaded successfully!")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Model loaded successfully!

# %%
(_, _), (x_test, y_test) = keras.datasets.mnist.load_data()

# Normalize the test data (same as before)
x_test = x_test.astype("float32") / 255.0

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f"\n✅ Test accuracy: {test_acc*100:.2f}%")
# Out:
# 313/313 - 1s - 3ms/step - accuracy: 0.9735 - loss: 0.0849
#
# ✅ Test accuracy: 97.35%

# %%
# Make predictions on the first 5 test images
predictions = model.predict(x_test[:5])

# Display images and predictions
for i in range(5):
    plt.imshow(x_test[i], cmap="gray")
    plt.title(f"Predicted: {np.argmax(predictions[i])}, Actual: {y_test[i]}")
    plt.axis("off")
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
